# %% [markdown]
# <a href="https://colab.research.google.com/github/Nawaf9997/Traffic_Anlysis/blob/main/Task_1_Week_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tasks

# %% [markdown]
# ## 1.Data Merging and cleaning

# %% [markdown]
# ### Merge the two dataframes

# %%
import pandas as pd
df = pd.read_csv('/content/Dataset 1.csv')
df1 = pd.read_csv('/content/Dataset 2.csv')
# Out:
# <ipython-input-10-c36eebf6c7f0>:2: DtypeWarning: Columns (31) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/content/Dataset 1.csv')

# %%
pd.options.display.max_columns = None
pd.options.display.max_rows = None

# %%
df.head()
# Out:
#   Accident_Index  Location_Easting_OSGR  Location_Northing_OSGR  Longitude  \
# 0  200501BS00001               525680.0                178240.0  -0.191170
# 1  200501BS00002               524170.0                181650.0  -0.211708
# 2  200501BS00003               524520.0                182240.0  -0.206458
# 3  200501BS00004               526900.0                177530.0  -0.173862
# 4  200501BS00005               528060.0                179040.0  -0.156618
#
#     Latitude  Police_Force  Accident_Severity  Number_of_Vehicles  \
# 0  51.489096             1                  2                   1
# 1  51.520075             1                  3                   1
# 2  51.525301             1                  3                   2
# 3  51.482442             1                  3                   1
# 4  51.495752             1                  3                   1
#
#    Number_of_Casualties        Date  Day_of_Week   Time  \
# 0                     1  04/01/2005            3  17:42
# ...

# %%
df1.head()
# Out:
#   Accident_Index  Vehicle_Reference  Casualty_Reference  Casualty_Class  \
# 0  200501BS00001                  1                   1               3
# 1  200501BS00002                  1                   1               2
# 2  200501BS00003                  2                   1               1
# 3  200501BS00004                  1                   1               3
# 4  200501BS00005                  1                   1               1
#
#    Sex_of_Casualty  Age_of_Casualty  Age_Band_of_Casualty  Casualty_Severity  \
# 0                1               37                     7                  2
# 1                1               37                     7                  3
# 2                1               62                     9                  3
# 3                1               30                     6                  3
# 4                1               49                     8                  3
#
#    Pedestrian_Location  Pedestrian_Movement  Car_Passenger  \
# ...

# %%
df.columns
# Out:
# Index(['Accident_Index', 'Location_Easting_OSGR', 'Location_Northing_OSGR',
#        'Longitude', 'Latitude', 'Police_Force', 'Accident_Severity',
#        'Number_of_Vehicles', 'Number_of_Casualties', 'Date', 'Day_of_Week',
#        'Time', 'Local_Authority_(District)', 'Local_Authority_(Highway)',
#        '1st_Road_Class', '1st_Road_Number', 'Road_Type', 'Speed_limit',
#        'Junction_Detail', 'Junction_Control', '2nd_Road_Class',
#        '2nd_Road_Number', 'Pedestrian_Crossing-Human_Control',
#        'Pedestrian_Crossing-Physical_Facilities', 'Light_Conditions',
#        'Weather_Conditions', 'Road_Surface_Conditions',
#        'Special_Conditions_at_Site', 'Carriageway_Hazards',
#        'Urban_or_Rural_Area', 'Did_Police_Officer_Attend_Scene_of_Accident',
#        'LSOA_of_Accident_Location'],
#       dtype='object')

# %%
df1.columns
# Out:
# Index(['Accident_Index', 'Vehicle_Reference', 'Casualty_Reference',
#        'Casualty_Class', 'Sex_of_Casualty', 'Age_of_Casualty',
#        'Age_Band_of_Casualty', 'Casualty_Severity', 'Pedestrian_Location',
#        'Pedestrian_Movement', 'Car_Passenger', 'Bus_or_Coach_Passenger',
#        'Pedestrian_Road_Maintenance_Worker', 'Casualty_Type',
#        'Casualty_Home_Area_Type'],
#       dtype='object')

# %%
dfmrgd = pd.merge(df, df1,on="Accident_Index" ,how='inner')

# %%
dfmrgd.head()
# Out:
#   Accident_Index  Location_Easting_OSGR  Location_Northing_OSGR  Longitude  \
# 0  200501BS00001               525680.0                178240.0  -0.191170
# 1  200501BS00002               524170.0                181650.0  -0.211708
# 2  200501BS00003               524520.0                182240.0  -0.206458
# 3  200501BS00004               526900.0                177530.0  -0.173862
# 4  200501BS00005               528060.0                179040.0  -0.156618
#
#     Latitude  Police_Force  Accident_Severity  Number_of_Vehicles  \
# 0  51.489096             1                  2                   1
# 1  51.520075             1                  3                   1
# 2  51.525301             1                  3                   2
# 3  51.482442             1                  3                   1
# 4  51.495752             1                  3                   1
#
#    Number_of_Casualties        Date  Day_of_Week   Time  \
# 0                     1  04/01/2005            3  17:42
# ...

# %%
dfmrgd.columns
# Out:
# Index(['Accident_Index', 'Location_Easting_OSGR', 'Location_Northing_OSGR',
#        'Longitude', 'Latitude', 'Police_Force', 'Accident_Severity',
#        'Number_of_Vehicles', 'Number_of_Casualties', 'Date', 'Day_of_Week',
#        'Time', 'Local_Authority_(District)', 'Local_Authority_(Highway)',
#        '1st_Road_Class', '1st_Road_Number', 'Road_Type', 'Speed_limit',
#        'Junction_Detail', 'Junction_Control', '2nd_Road_Class',
#        '2nd_Road_Number', 'Pedestrian_Crossing-Human_Control',
#        'Pedestrian_Crossing-Physical_Facilities', 'Light_Conditions',
#        'Weather_Conditions', 'Road_Surface_Conditions',
#        'Special_Conditions_at_Site', 'Carriageway_Hazards',
#        'Urban_or_Rural_Area', 'Did_Police_Officer_Attend_Scene_of_Accident',
#        'LSOA_of_Accident_Location', 'Vehicle_Reference', 'Casualty_Reference',
#        'Casualty_Class', 'Sex_of_Casualty', 'Age_of_Casualty',
# ...

# %%
dfmrgd.shape
# Out:
# (2216720, 46)

# %%
dfmrgd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2216720 entries, 0 to 2216719
# Data columns (total 46 columns):
#  #   Column                                       Dtype
# ---  ------                                       -----
#  0   Accident_Index                               object
#  1   Location_Easting_OSGR                        float64
#  2   Location_Northing_OSGR                       float64
#  3   Longitude                                    float64
#  4   Latitude                                     float64
#  5   Police_Force                                 int64
#  6   Accident_Severity                            int64
#  7   Number_of_Vehicles                           int64
#  8   Number_of_Casualties                         int64
#  9   Date                                         object
#  10  Day_of_Week                                  int64
#  11  Time                                         object
#  12  Local_Authority_(District)                   int64
# ...

# %%
import pandas as pd
df = pd.read_csv('/content/Dataset 1.csv')
df1 = pd.read_csv('/content/Dataset 2.csv')
# Out:
# <ipython-input-21-c36eebf6c7f0>:2: DtypeWarning: Columns (31) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/content/Dataset 1.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1640597 entries, 0 to 1640596
# Data columns (total 32 columns):
#  #   Column                                       Non-Null Count    Dtype
# ---  ------                                       --------------    -----
#  0   Accident_Index                               1640597 non-null  object
#  1   Location_Easting_OSGR                        1640486 non-null  float64
#  2   Location_Northing_OSGR                       1640486 non-null  float64
#  3   Longitude                                    1640486 non-null  float64
#  4   Latitude                                     1640486 non-null  float64
#  5   Police_Force                                 1640597 non-null  int64
#  6   Accident_Severity                            1640597 non-null  int64
#  7   Number_of_Vehicles                           1640597 non-null  int64
#  8   Number_of_Casualties                         1640597 non-null  int64
# ...

# %%
df.isna().sum()
# Out:
# Accident_Index                                      0
# Location_Easting_OSGR                             111
# Location_Northing_OSGR                            111
# Longitude                                         111
# Latitude                                          111
# Police_Force                                        0
# Accident_Severity                                   0
# Number_of_Vehicles                                  0
# Number_of_Casualties                                0
# Date                                                0
# Day_of_Week                                         0
# Time                                              133
# Local_Authority_(District)                          0
# Local_Authority_(Highway)                           0
# 1st_Road_Class                                      0
# 1st_Road_Number                                     0
# Road_Type                                           0
# ...

# %%
df["Location_Easting_OSGR"].mode()
# Out:
# 0    533650.0
# Name: Location_Easting_OSGR, dtype: float64

# %%
df["Location_Easting_OSGR"].fillna("533650.0",inplace=True)
# Out:
# <ipython-input-25-dd32170e2004>:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '533650.0' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df["Location_Easting_OSGR"].fillna("533650.0",inplace=True)

# %%
df['Location_Northing_OSGR'].mode()
# Out:
# 0    181310.0
# Name: Location_Northing_OSGR, dtype: float64

# %%
df["Location_Northing_OSGR"].fillna("181310.0",inplace=True)
# Out:
# <ipython-input-27-f9586cffefe6>:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '181310.0' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df["Location_Northing_OSGR"].fillna("181310.0",inplace=True)

# %%
df["Longitude"].mode()
# Out:
# 0   -0.977611
# Name: Longitude, dtype: float64

# %%
df["Longitude"].fillna("-0.977611",inplace=True)
# Out:
# <ipython-input-29-263823216fc2>:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '-0.977611' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df["Longitude"].fillna("-0.977611",inplace=True)

# %%
df["Latitude"].mode()
# Out:
# 0    52.458798
# Name: Latitude, dtype: float64

# %%
df["Latitude"].fillna("52.458798",inplace=True)
# Out:
# <ipython-input-31-a4b7e15d16a9>:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '52.458798' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df["Latitude"].fillna("52.458798",inplace=True)

# %%
df["Time"].mode()
# Out:
# 0    17:00
# Name: Time, dtype: object

# %%
df["Time"].fillna("17:00",inplace=True)

# %%
df["LSOA_of_Accident_Location"].mode()
# Out:
# 0    E01000004
# Name: LSOA_of_Accident_Location, dtype: object

# %%
df["LSOA_of_Accident_Location"].fillna("E01000004",inplace=True)

# %%
df.isna().sum()
# Out:
# Accident_Index                                 0
# Location_Easting_OSGR                          0
# Location_Northing_OSGR                         0
# Longitude                                      0
# Latitude                                       0
# Police_Force                                   0
# Accident_Severity                              0
# Number_of_Vehicles                             0
# Number_of_Casualties                           0
# Date                                           0
# Day_of_Week                                    0
# Time                                           0
# Local_Authority_(District)                     0
# Local_Authority_(Highway)                      0
# 1st_Road_Class                                 0
# 1st_Road_Number                                0
# Road_Type                                      0
# Speed_limit                                    0
# Junction_Detail                                0
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2216720 entries, 0 to 2216719
# Data columns (total 15 columns):
#  #   Column                              Dtype
# ---  ------                              -----
#  0   Accident_Index                      object
#  1   Vehicle_Reference                   int64
#  2   Casualty_Reference                  int64
#  3   Casualty_Class                      int64
#  4   Sex_of_Casualty                     int64
#  5   Age_of_Casualty                     int64
#  6   Age_Band_of_Casualty                int64
#  7   Casualty_Severity                   int64
#  8   Pedestrian_Location                 int64
#  9   Pedestrian_Movement                 int64
#  10  Car_Passenger                       int64
#  11  Bus_or_Coach_Passenger              int64
#  12  Pedestrian_Road_Maintenance_Worker  int64
#  13  Casualty_Type                       int64
#  14  Casualty_Home_Area_Type             int64
# dtypes: int64(14), object(1)
# ...

# %%
df1.isna().sum()
# Out:
# Accident_Index                        0
# Vehicle_Reference                     0
# Casualty_Reference                    0
# Casualty_Class                        0
# Sex_of_Casualty                       0
# Age_of_Casualty                       0
# Age_Band_of_Casualty                  0
# Casualty_Severity                     0
# Pedestrian_Location                   0
# Pedestrian_Movement                   0
# Car_Passenger                         0
# Bus_or_Coach_Passenger                0
# Pedestrian_Road_Maintenance_Worker    0
# Casualty_Type                         0
# Casualty_Home_Area_Type               0
# dtype: int64

# %%
pd.options.display.max_columns = None
pd.options.display.max_rows = None

# %%
dfmrgd = pd.merge(df, df1,on="Accident_Index" ,how='inner')

# %%
dfmrgd.head()
# Out:
#   Accident_Index Location_Easting_OSGR Location_Northing_OSGR Longitude  \
# 0  200501BS00001              525680.0               178240.0  -0.19117
# 1  200501BS00002              524170.0               181650.0 -0.211708
# 2  200501BS00003              524520.0               182240.0 -0.206458
# 3  200501BS00004              526900.0               177530.0 -0.173862
# 4  200501BS00005              528060.0               179040.0 -0.156618
#
#     Latitude  Police_Force  Accident_Severity  Number_of_Vehicles  \
# 0  51.489096             1                  2                   1
# 1  51.520075             1                  3                   1
# 2  51.525301             1                  3                   2
# 3  51.482442             1                  3                   1
# 4  51.495752             1                  3                   1
#
#    Number_of_Casualties        Date  Day_of_Week   Time  \
# 0                     1  04/01/2005            3  17:42
# ...

# %% [markdown]
# ## 2. Exploratory Data Analysis:

# %% [markdown]
# ### Perform summary statistics on the dataset.

# %%
dfmrgd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2216720 entries, 0 to 2216719
# Data columns (total 46 columns):
#  #   Column                                       Dtype
# ---  ------                                       -----
#  0   Accident_Index                               object
#  1   Location_Easting_OSGR                        object
#  2   Location_Northing_OSGR                       object
#  3   Longitude                                    object
#  4   Latitude                                     object
#  5   Police_Force                                 int64
#  6   Accident_Severity                            int64
#  7   Number_of_Vehicles                           int64
#  8   Number_of_Casualties                         int64
#  9   Date                                         object
#  10  Day_of_Week                                  int64
#  11  Time                                         object
#  12  Local_Authority_(District)                   int64
# ...

# %%
dfmrgd.sample(10)
# Out:
#         Accident_Index Location_Easting_OSGR Location_Northing_OSGR Longitude  \
# 917862   2008400D02278              493690.0               240590.0 -0.634971
# 1821081  2012620214578              274150.0               194580.0 -3.819947
# 2127020  2014331400344              469420.0               293425.0 -0.978001
# 225350   2005520026484              359580.0               174480.0 -2.583308
# 1072003  2009120018070              504140.0               487350.0 -0.402315
# 2138514  201437EA84049              610573.0               239392.0  1.067104
# 510593   200663BC09406              237910.0               246290.0 -4.367466
# 1494014  2011100381211              417420.0               561320.0  -1.72957
# 1328178  201022F002283              341210.0               317010.0 -2.872396
# 869601   200820E134601              401210.0               279180.0 -1.983649
#
#           Latitude  Police_Force  Accident_Severity  Number_of_Vehicles  \
# ...

# %% [markdown]
# ### Identify and analyze patterns in the data.

# %%
dfmrgd.describe()
# Out:
#        Police_Force  Accident_Severity  Number_of_Vehicles  \
# count  2.216720e+06       2.216720e+06        2.216720e+06
# mean   3.091263e+01       2.817538e+00        1.934206e+00
# std    2.522360e+01       4.308973e-01        9.010872e-01
# min    1.000000e+00       1.000000e+00        1.000000e+00
# 25%    7.000000e+00       3.000000e+00        1.000000e+00
# 50%    3.100000e+01       3.000000e+00        2.000000e+00
# 75%    4.600000e+01       3.000000e+00        2.000000e+00
# max    9.800000e+01       3.000000e+00        6.700000e+01
#
#        Number_of_Casualties   Day_of_Week  Local_Authority_(District)  \
# count          2.216720e+06  2.216720e+06                2.216720e+06
# mean           1.856240e+00  4.115620e+00                3.561148e+02
# std            2.044728e+00  1.954008e+00                2.561145e+02
# min            1.000000e+00  1.000000e+00                1.000000e+00
# 25%            1.000000e+00  2.000000e+00                1.290000e+02
# ...

# %%
dfmrgd = dfmrgd.drop(columns=[
    'Location_Easting_OSGR', 'Location_Northing_OSGR', 'Longitude', 'Latitude',
    'Pedestrian_Crossing-Human_Control', 'Pedestrian_Crossing-Physical_Facilities',
    'Bus_or_Coach_Passenger', 'Pedestrian_Road_Maintenance_Worker'
], errors='ignore')

# %%
print(dfmrgd.columns)
# Out:
# Index(['Accident_Index', 'Police_Force', 'Accident_Severity',
#        'Number_of_Vehicles', 'Number_of_Casualties', 'Date', 'Day_of_Week',
#        'Time', 'Local_Authority_(District)', 'Local_Authority_(Highway)',
#        '1st_Road_Class', '1st_Road_Number', 'Road_Type', 'Speed_limit',
#        'Junction_Detail', 'Junction_Control', '2nd_Road_Class',
#        '2nd_Road_Number', 'Light_Conditions', 'Weather_Conditions',
#        'Road_Surface_Conditions', 'Special_Conditions_at_Site',
#        'Carriageway_Hazards', 'Urban_or_Rural_Area',
#        'Did_Police_Officer_Attend_Scene_of_Accident',
#        'LSOA_of_Accident_Location', 'Vehicle_Reference', 'Casualty_Reference',
#        'Casualty_Class', 'Sex_of_Casualty', 'Age_of_Casualty',
#        'Age_Band_of_Casualty', 'Casualty_Severity', 'Pedestrian_Location',
#        'Pedestrian_Movement', 'Car_Passenger', 'Casualty_Type',
#        'Casualty_Home_Area_Type'],
#       dtype='object')

# %%
dfmrgd.tail()
# Out:
#         Accident_Index  Police_Force  Accident_Severity  Number_of_Vehicles  \
# 2216715  2014984137714            98                  3                   1
# 2216716  2014984138414            98                  2                   3
# 2216717  2014984138414            98                  2                   3
# 2216718  2014984139614            98                  3                   2
# 2216719  2014984139614            98                  3                   2
#
#          Number_of_Casualties        Date  Day_of_Week   Time  \
# 2216715                     1  09/12/2014            3  02:00
# 2216716                     2  17/12/2014            4  06:55
# 2216717                     2  17/12/2014            4  06:55
# 2216718                     2  24/12/2014            4  15:00
# 2216719                     2  24/12/2014            4  15:00
#
#          Local_Authority_(District) Local_Authority_(Highway)  1st_Road_Class  \
# ...

# %%
dfmrgd['Sex_of_Casualty']  = dfmrgd['Sex_of_Casualty'] .apply(str)

# %%
dfmrgd['Sex_of_Casualty'] = dfmrgd['Sex_of_Casualty'].apply(lambda x: str(x).replace( "1" , 'male'))
dfmrgd['Sex_of_Casualty'] = dfmrgd['Sex_of_Casualty'].apply(lambda x: str(x).replace( "2" , 'female'))

# %%
dfmrgd.head()
# Out:
#   Accident_Index  Police_Force  Accident_Severity  Number_of_Vehicles  \
# 0  200501BS00001             1                  2                   1
# 1  200501BS00002             1                  3                   1
# 2  200501BS00003             1                  3                   2
# 3  200501BS00004             1                  3                   1
# 4  200501BS00005             1                  3                   1
#
#    Number_of_Casualties        Date  Day_of_Week   Time  \
# 0                     1  04/01/2005            3  17:42
# 1                     1  05/01/2005            4  17:36
# 2                     1  06/01/2005            5  00:15
# 3                     1  07/01/2005            6  10:35
# 4                     1  10/01/2005            2  21:13
#
#    Local_Authority_(District) Local_Authority_(Highway)  1st_Road_Class  \
# 0                          12                 E09000020               3
# ...

# %%
dfmrgd.sample(10)
# Out:
#         Accident_Index  Police_Force  Accident_Severity  Number_of_Vehicles  \
# 435652   200642I325708            42                  3                   2
# 1270031  201005DD05906             5                  3                   1
# 1510609  201114B040311            14                  3                   2
# 2039356  201401QA10386             1                  3                   1
# 1472784  201104CM11053             4                  3                   3
# 1317244  201020M005100            20                  3                   2
# 909705   2008350420908            35                  3                   1
# 251476   200563AC59905            63                  3                   2
# 233062   2005530183343            53                  2                   3
# 646911   2007230796791            23                  2                   2
#
#          Number_of_Casualties        Date  Day_of_Week   Time  \
# 435652                      1  16/08/2006            4  15:57
# ...

# %%
dfmrgd['Day_of_Week']  = dfmrgd['Day_of_Week'] .apply(str)

# %%
dfmrgd['Day_of_Week'] = dfmrgd['Day_of_Week'].apply(lambda x: str(x).replace( "1" , 'Sunday '))
dfmrgd['Day_of_Week'] = dfmrgd['Day_of_Week'].apply(lambda x: str(x).replace( "2" , 'Monday '))
dfmrgd['Day_of_Week'] = dfmrgd['Day_of_Week'].apply(lambda x: str(x).replace( "3" , 'Tuesday'))
dfmrgd['Day_of_Week'] = dfmrgd['Day_of_Week'].apply(lambda x: str(x).replace( "4" , 'Wednesday'))
dfmrgd['Day_of_Week'] = dfmrgd['Day_of_Week'].apply(lambda x: str(x).replace( "5" , 'Thursday'))
dfmrgd['Day_of_Week'] = dfmrgd['Day_of_Week'].apply(lambda x: str(x).replace( "6" , 'Friday'))
dfmrgd['Day_of_Week'] = dfmrgd['Day_of_Week'].apply(lambda x: str(x).replace( "7" , 'Saturday'))

# %%
dfmrgd.sample(10)
# Out:
#         Accident_Index  Police_Force  Accident_Severity  Number_of_Vehicles  \
# 1720301  201220G003952            20                  3                   3
# 1489728  2011070206711             7                  3                   1
# 1253769  201001XD80030             1                  3                   2
# 1501594  2011130031207            13                  3                   2
# 1794065  2012460218029            46                  3                   2
# 95019    200514C053705            14                  2                   2
# 313224   200605BB10519             5                  3                   2
# 1797609  2012471201729            47                  3                   2
# 913017   200836T080188            36                  3                   1
# 1450492  201101MM70541             1                  3                   2
#
#          Number_of_Casualties        Date Day_of_Week   Time  \
# 1720301                     1  11/04/2012   Wednesday  17:15
# ...

# %%
dfmrgd['Did_Police_Officer_Attend_Scene_of_Accident']  = dfmrgd['Did_Police_Officer_Attend_Scene_of_Accident'] .apply(str)

# %%
dfmrgd['Did_Police_Officer_Attend_Scene_of_Accident'] = dfmrgd['Did_Police_Officer_Attend_Scene_of_Accident'].apply(lambda x: str(x).replace( "1" , 'YES'))
dfmrgd['Did_Police_Officer_Attend_Scene_of_Accident'] = dfmrgd['Did_Police_Officer_Attend_Scene_of_Accident'].apply(lambda x: str(x).replace( "2" , 'NO'))

# %%
dfmrgd.sample(2)
# Out:
#         Accident_Index  Police_Force  Accident_Severity  Number_of_Vehicles  \
# 1391424  2010460190919            46                  3                   1
# 465028   2006460124112            46                  3                   2
#
#          Number_of_Casualties        Date Day_of_Week   Time  \
# 1391424                     5  13/09/2010     Monday   14:55
# 465028                      3  02/04/2006     Sunday   14:23
#
#          Local_Authority_(District) Local_Authority_(Highway)  1st_Road_Class  \
# 1391424                         533                 E10000016               3
# 465028                          536                 E10000016               4
#
#          1st_Road_Number  Road_Type  Speed_limit  Junction_Detail  \
# 1391424              256          3           70                1
# 465028              2163          6           60                0
#
#          Junction_Control  2nd_Road_Class  2nd_Road_Number  Light_Conditions  \
# ...

# %%
dfmrgd.duplicated().sum()
# Out:
# 0

# %%
dfmrgd = dfmrgd.drop_duplicates()

# %%
from google.colab import files
dfmrgd.to_csv('dfmrgd.csv', encoding = 'utf-8-sig')
files.download('dfmrgd.csv')

# %% [markdown]
# ## 3. Data visualization

# %% [markdown]
# ### Create visualizations to illustrate the findings from the EDA.

# %%
# now we can do the heatmap :

sns.heatmap(dfmrgd , annot= True)
plt.title("how parent's Education effect on student's score")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-73-9eafae47b2f3> in <cell line: 3>()
#       1 # now we can do the heatmap :
#       2
# ----> 3 sns.heatmap(dfmrgd , annot= True)
#       4 plt.title("how parent's Education effect on student's score")
#       5 plt.show()
#
# /usr/local/lib/python3.10/dist-packages/seaborn/matrix.py in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     444     """
#     445     # Initialize the plotter object
# --> 446     plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     447                           annot_kws, cbar, cbar_kws, xticklabels,
#     448                           yticklabels, mask)
#
# ...

# %% [markdown]
# ### Use appropriate plots such as histograms, bar charts, pie charts, scatter plots, and heatmaps.

# %% [markdown]
# ## 4. Applying Machine Learning Model
#
# *   List item
# *   List item

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

df = pd.read_csv('/content/dfmrgd.csv')

X = df.drop(columns=['Day_of_Week'])
y = df['Time']
# Out:
# <ipython-input-67-2fa0d73e334e>:5: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/content/dfmrgd.csv')

# %% [markdown]
# ### Initialize your model

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# ### Train and Test your model

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

df = pd.read_csv('/content/dfmrgd.csv')

# Identify columns with object (string) dtype
object_cols = df.select_dtypes(include='object').columns

# Option 1: Drop non-numerical columns (if they are not relevant for your model)
X = df.drop(columns=['Day_of_Week'] + list(object_cols))

# Option 2: Encode categorical features (if they are relevant)
# You'll need to choose an appropriate encoding method (e.g., one-hot encoding, label encoding)
# Example using one-hot encoding:
# from sklearn.preprocessing import OneHotEncoder
# encoder = OneHotEncoder()
# encoded_data = encoder.fit_transform(df[object_cols])
# # ... integrate encoded data into your feature matrix X

y = df['Time']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
# Out:
# <ipython-input-71-4b6bd25be5fb>:5: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/content/dfmrgd.csv')
