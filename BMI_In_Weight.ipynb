# %% [markdown]
# <a href="https://colab.research.google.com/github/Nawaf9997/Traffic_Anlysis/blob/main/BMI_In_Weight.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import OneHotEncoder, LabelEncoder

# %%
df = pd.read_csv('/content/500_Person_Gender_Height_Weight_Index.csv')
df
# Out:
#      Gender  Height  Weight  Index
# 0      Male     174      96      4
# 1      Male     189      87      2
# 2    Female     185     110      4
# 3    Female     195     104      3
# 4      Male     149      61      3
# ..      ...     ...     ...    ...
# 495  Female     150     153      5
# 496  Female     184     121      4
# 497  Female     141     136      5
# 498    Male     150      95      5
# 499    Male     173     131      5
#
# [500 rows x 4 columns]

# %%
df["Height_M"] = df["Height"]/100
df
# Out:
#      Gender  Height  Weight  Index  Height_M
# 0      Male     174      96      4      1.74
# 1      Male     189      87      2      1.89
# 2    Female     185     110      4      1.85
# 3    Female     195     104      3      1.95
# 4      Male     149      61      3      1.49
# ..      ...     ...     ...    ...       ...
# 495  Female     150     153      5      1.50
# 496  Female     184     121      4      1.84
# 497  Female     141     136      5      1.41
# 498    Male     150      95      5      1.50
# 499    Male     173     131      5      1.73
#
# [500 rows x 5 columns]

# %%
df["BMI"] = df["Weight"]/(df["Height"] ** 2)
df
# Out:
#      Gender  Height  Weight  Index  Height_M       BMI
# 0      Male     174      96      4      1.74  0.003171
# 1      Male     189      87      2      1.89  0.002436
# 2    Female     185     110      4      1.85  0.003214
# 3    Female     195     104      3      1.95  0.002735
# 4      Male     149      61      3      1.49  0.002748
# ..      ...     ...     ...    ...       ...       ...
# 495  Female     150     153      5      1.50  0.006800
# 496  Female     184     121      4      1.84  0.003574
# 497  Female     141     136      5      1.41  0.006841
# 498    Male     150      95      5      1.50  0.004222
# 499    Male     173     131      5      1.73  0.004377
#
# [500 rows x 6 columns]
